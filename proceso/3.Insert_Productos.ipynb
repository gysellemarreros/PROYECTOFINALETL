-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType
from pyspark.sql.functions import current_timestamp, to_timestamp, concat, col, lit

-- %%
%python
dbutils.widgets.text("container", "raw")
dbutils.widgets.text("catalogo", "catalog_au")
dbutils.widgets.text("esquema", "bronze")
dbutils.widgets.text("storageName", "adlsproyectofinaletl")

-- %%
%python
container = dbutils.widgets.get("container")
catalogo = dbutils.widgets.get("catalogo")
esquema = dbutils.widgets.get("esquema")
storageName = dbutils.widgets.get("storageName")

ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/producto.csv"

-- %%
%python
constructors_schema = StructType(fields=[
    StructField("descripcion", StringType(), False),
    StructField("CodProducto", StringType(), True),
    StructField("precio", DoubleType(), True)
])

-- %%
%python
producto_df = spark.read \
            .option("header", True) \
            .schema(producto_schema) \
            .csv(ruta)

-- %%
%python
producto_final_df = df_producto.select(
    col("CodProducto").alias("id_producto")
)

-- %%
%python
producto_final_df.write.mode("overwrite").insertInto(f"{catalogo}.{esquema}.producto")
